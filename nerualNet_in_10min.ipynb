# %% [markdown]
# <a href="https://colab.research.google.com/github/baldhakal/30-Days-Of-JavaScript/blob/master/nerualNet_in_10min.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing tensorflow
import tensorflow as tf
from tensorflow import keras

#Neural net
model = tf.keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])
model.compile(optimizer='sgd',loss='mean_squared_error')

#Input Data
num_of_flats = (1,2,3,4,5,6,7)
price_of_house = (10000,20000,30000,40000,50000,60000,70000)

#Training Neural Net
model.fit(num_of_flats,price_of_house,epochs = 500)

#Predicting the price of a house with 10 flats
print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 412ms/step - loss: 2000528256.0000
# Epoch 2/500
# 1/1 [==============================] - 0s 4ms/step - loss: 682420032.0000
# Epoch 3/500
# 1/1 [==============================] - 0s 3ms/step - loss: 233106720.0000
# Epoch 4/500
# 1/1 [==============================] - 0s 3ms/step - loss: 79943496.0000
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 27730350.0000
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 9928499.0000
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3856636.7500
# Epoch 8/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1783274.1250
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1072921.3750
# Epoch 10/500
# 1/1 [==============================] - 0s 4ms/step - loss: 827214.1875
# Epoch 11/500
# 1/1 [==============================] - 0s 3ms/step - loss: 739915.0625
# Epoch 12/500
# ...
